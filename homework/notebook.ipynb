# %% [markdown]
# # Paso 1: Limpieza de los dataset

# %% [markdown]
# ### Cargar Dataset

# %%
import pandas as pd

train_data = pd.read_csv("../files/input/train_data.csv.zip")
test_data = pd.read_csv("../files/input/test_data.csv.zip")

# %%
train_data.head(5)

# %%
test_data.head(5)

# %%
print(train_data.columns)
print(test_data.columns)

# %% [markdown]
# ## Procesamiento de la data

# %% [markdown]
# ### Renombrar columnas

# %%
# Renombre la columna "default payment next month" a "default".
train_data.rename(columns={"default payment next month": "default"}, inplace=True)
test_data.rename(columns={"default payment next month": "default"}, inplace=True)
print(train_data.columns)
print(test_data.columns)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %% [markdown]
# ### Eliminar columnas

# %%
# Remueva la columna "ID".
train_data.drop(["ID"], axis=1, inplace=True)
test_data.drop(["ID"], axis=1, inplace=True)
print(train_data.columns)
print(test_data.columns)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %% [markdown]
# ### Eliminar registros con datos faltantes

# %%
# Elimine los registros con informacion no disponible.
print("Train data missing values",train_data.isnull().sum())
print("Test data missing values",test_data.isnull().sum())
# Out:
# Train data missing values LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# default      0
# dtype: int64
# Test data missing values LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# default      0
# dtype: int64

# %%
train_data.dropna()
test_data.dropna()
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        120000    2          2         2   26     -1      2      0      0
# 1         20000    1          3         2   35     -2     -2     -2     -2
# 2        200000    2          3         2   34      0      0      2      0
# 3        250000    1          1         2   29      0      0      0      0
# 4         50000    2          3         3   23      1      2      0      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 8995      20000    1          2         1   44     -2     -2     -2     -2
# 8996     360000    1          1         2   35     -1     -1     -2     -2
# 8997     150000    1          1         2   35     -1     -1     -1     -1
# 8998      30000    1          2         2   37      4      3      2     -1
# 8999      50000    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# ### Agrupar valores en categoría común

# %%
# Para la columna EDUCATION, valores > 4 indican niveles superiores de educación, agrupe estos valores en la categoría "others".
train_data['EDUCATION'] = train_data['EDUCATION'].apply(lambda x: 4 if x > 4 else x)
test_data['EDUCATION'] = test_data['EDUCATION'].apply(lambda x: 4 if x > 4 else x)

# %% [markdown]
# # Paso 2: Dividir los datasets

# %% [markdown]
# Dividir los datasets en x_train, y_train, x_test, y_test

# %%
x_train = train_data.drop("default", axis=1)
x_train.head(3)
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0     310000    1          3         1   32      0      0      0      0
# 1      10000    2          3         1   49     -1     -1     -2     -1
# 2      50000    1          2         1   28     -1     -1     -1      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...     110375      84373      57779      14163      8295      6000
# 1      2  ...       -748       1690       1138        930         0         0
# 2     -1  ...      46257      45975       1300      43987         0     46257
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0      4000      3000      1000      2000
# 1      2828         0       182         0
# 2      2200      1300     43987      1386
#
# [3 rows x 23 columns]

# %%
y_train = train_data["default"]
y_train.head(3)
# Out:
# 0    0
# 1    1
# 2    0
# Name: default, dtype: int64

# %%
x_test = test_data.drop("default", axis=1)
x_test.head(3)
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0     120000    2          2         2   26     -1      2      0      0
# 1      20000    1          3         2   35     -2     -2     -2     -2
# 2     200000    2          3         2   34      0      0      2      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...       2682       3272       3455       3261         0      1000
# 1     -1  ...          0          0      13007      13912         0         0
# 2      0  ...       5535       2513       1828       3731      2306        12
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0      1000      1000         0      2000
# 1         0     13007      1122         0
# 2        50       300      3738        66
#
# [3 rows x 23 columns]

# %%
y_test = test_data["default"]
y_test.head(3)
# Out:
# 0    1
# 1    0
# 2    0
# Name: default, dtype: int64

# %% [markdown]
# # Paso 3: pipeline para modelo de clasificación

# %% [markdown]
# Este pipeline debe contener las siguientes capas:
# - Transforma las variables categoricas usando el método one-hot-encoding.
# - Ajusta un modelo de bosques aleatorios (rando forest).

# %% [markdown]
# ### Transformadores

# %%
# Transforma las variables categoricas usando el método one-hot-encoding
from sklearn.preprocessing import OneHotEncoder

oneHotEncoder = OneHotEncoder()

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_selector

column_trans = ColumnTransformer(
    transformers=[
        # ("scale", StandardScaler(), make_column_selector(dtype_include=np.number)),
        ("oneHotEncoder", oneHotEncoder, make_column_selector(dtype_include=object)),
    ],
    remainder="passthrough",
)

# %% [markdown]
# ### Clasificador

# %%
# Ajusta un modelo de bosques aleatorios (random forest)
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_jobs=-1, random_state=42)

# %% [markdown]
# ## Pipeline

# %%
estimators = [
    ("preprocessor", column_trans),
    ("rf", rf),
]

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline(
    steps=estimators,
    verbose=False,
)

# %%
pipeline.steps
# Out:
# [('preprocessor',
#   ColumnTransformer(remainder='passthrough',
#                     transformers=[('oneHotEncoder', OneHotEncoder(),
#                                    <sklearn.compose._column_transformer.make_column_selector object at 0x000001F53FD5A330>)])),
#  ('rf', RandomForestClassifier(n_jobs=-1, random_state=42))]

# %% [markdown]
# # Paso 4: Optimizar los hiperparámetros del pipeline

# %% [markdown]
# Optimice los hiperparametros del pipeline usando validación cruzada.
#
# - Use 10 splits para la validación cruzada.
# - Use la función de precision balanceada para medir la precisión del modelo.

# %%
from sklearn.model_selection import ParameterGrid

param_grid = {
    'rf__n_estimators': [900,],
    'rf__max_depth': [25],
    'rf__min_samples_split': [8],
    'rf__min_samples_leaf': [2,],
    'rf__max_features': ["sqrt"],
    # 'rf__class_weight' : ["balanced"],
}

list(ParameterGrid(param_grid))
# Out:
# [{'rf__max_depth': 25,
#   'rf__max_features': 'sqrt',
#   'rf__min_samples_leaf': 2,
#   'rf__min_samples_split': 8,
#   'rf__n_estimators': 900}]

# %% [markdown]
# ## `RandomizedSearchCV`

# %%
from sklearn.model_selection import RandomizedSearchCV

randomizedSearchCV = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=5,
    cv=10,
    # --------------------------------------------------------------------------
    # Strategy to evaluate the performance of the cross-validated model on the
    # test set.
    scoring="balanced_accuracy",
    # --------------------------------------------------------------------------
    # Refit an estimator using the best found parameters on the whole dataset.
    refit=True,
    # --------------------------------------------------------------------------
    random_state=12345,
)

# %%
randomizedSearchCV.fit(x_train, y_train)

# %%
randomizedSearchCV.best_estimator_.named_steps["rf"]

# %%
randomizedSearchCV.best_score_

# %%
randomizedSearchCV.best_params_

# %%
randomizedSearchCV.predict(x_test)

# %% [markdown]
# ## `GridSearchCV`

# %%
from sklearn.model_selection import GridSearchCV

gridSearchCV = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=10,
    scoring="balanced_accuracy",
    refit=True,
    n_jobs=-1,
)

# %%
gridSearchCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('oneHotEncoder',
#                                                                          OneHotEncoder(),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x000001F53FD5A330>)])),
#                                        ('rf',
#                                         RandomForestClassifier(n_jobs=-1,
#                                                                random_state=42))]),
#              n_jobs=-1,
#              param_grid={'rf__max_depth': [25], 'rf__max_features': ['sqrt'],
#                          'rf__min_samples_leaf': [2],
#                          'rf__min_samples_split': [8],
# ...

# %%
gridSearchCV.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('oneHotEncoder',
#                                                   OneHotEncoder(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001F5414386B0>)])),
#                 ('rf',
#                  RandomForestClassifier(max_depth=25, min_samples_leaf=2,
#                                         min_samples_split=8, n_estimators=900,
#                                         n_jobs=-1, random_state=42))])

# %%
gridSearchCV.best_estimator_.named_steps['rf']
# Out:
# RandomForestClassifier(max_depth=25, min_samples_leaf=2, min_samples_split=8,
#                        n_estimators=900, n_jobs=-1, random_state=42)

# %%
gridSearchCV.best_score_
# Out:
# np.float64(0.656321980413979)

# %%
gridSearchCV.best_params_
# Out:
# {'rf__max_depth': 25,
#  'rf__max_features': 'sqrt',
#  'rf__min_samples_leaf': 2,
#  'rf__min_samples_split': 8,
#  'rf__n_estimators': 900}

# %% [markdown]
# Precision balanceada para medir la precisión del modelo

# %%
y_pred = gridSearchCV.predict(x_test)

# %%
from sklearn.metrics import balanced_accuracy_score

test_accuracy = balanced_accuracy_score(
    y_true=y_test,
    y_pred=y_pred,
)

print(f'Precisión balanceada en el conjunto de prueba: {test_accuracy:.4f}')
# Out:
# Precisión balanceada en el conjunto de prueba: 0.6743

# %% [markdown]
# Score del modelo

# %%
train_score = gridSearchCV.score(x_train, y_train)
test_score = gridSearchCV.score(x_test, y_test)


print(f'Score en el conjunto de prueba: {train_score:.4f}')
print(f'Score en el conjunto de testing: {test_score:.4f}')
# Out:
# Score en el conjunto de prueba: 0.8129
# Score en el conjunto de testing: 0.6743

# %%
train_score = gridSearchCV.best_estimator_.score(x_train, y_train)
test_score = gridSearchCV.best_estimator_.score(x_test, y_test)

print(f'Score en el conjunto de prueba: {train_score:.4f}')
print(f'Score en el conjunto de testing: {test_score:.4f}')
# Out:
# Score en el conjunto de prueba: 0.9136
# Score en el conjunto de testing: 0.8306

# %% [markdown]
# # Paso 5: Guardar el modelo

# %% [markdown]
# Guarde el modelo como "files/models/model.pkl".

# %%
model = gridSearchCV

# %%
import pickle

with open("../files/models/model.pkl", "wb") as file:
        pickle.dump(model, file)

# %% [markdown]
# # Paso 6. Calcular Métricas

# %% [markdown]
# Calcule las metricas de precision, precision balanceada, recall,y f1-score para los conjuntos de entrenamiento y prueba.

# %%
y_pred_train = gridSearchCV.best_estimator_.predict(x_train)

# %%
y_pred_test = gridSearchCV.best_estimator_.predict(x_test)

# %%
# Precisión
from sklearn.metrics import precision_score

train_precision = precision_score(
    y_true=y_train,
    y_pred=y_pred_train,
)

test_precision = precision_score(
    y_true=y_test,
    y_pred=y_pred_test,
)

print(f'Precision en el conjunto de prueba: {train_precision:.4f}')
print(f'Precision en el conjunto de testing: {test_precision:.4f}')

# %%
# Balanced accuracy
from sklearn.metrics import precision_score

train_balanced_accuracy = balanced_accuracy_score(
    y_true=y_train,
    y_pred=y_pred_train,
)

test_balanced_accuracy = balanced_accuracy_score(
    y_true=y_test,
    y_pred=y_pred_test,
)

print(f'Precision en el conjunto de prueba: {train_balanced_accuracy:.4f}')
print(f'Precision en el conjunto de testing: {test_balanced_accuracy:.4f}')

# %%
# Recall score
from sklearn.metrics import recall_score

train_recall = recall_score(
    y_true=y_train,
    y_pred=y_pred_train,
)

test_recall = recall_score(
    y_true=y_test,
    y_pred=y_pred_test,
)

print(f'Recall en el conjunto de prueba: {train_recall:.4f}')
print(f'Recall en el conjunto de testing: {test_recall:.4f}')

# %%
# F1 score
from sklearn.metrics import f1_score

train_f1 = f1_score(
    y_true=y_train,
    y_pred=y_pred_train,
)

test_f1 = f1_score(
    y_true=y_test,
    y_pred=y_pred_test,
)

print(f'F1 score en el conjunto de prueba: {train_f1:.4f}')
print(f'F1 score en el conjunto de testing: {test_f1:.4f}')

# %% [markdown]
# Cada fila del archivo es un diccionario con las metricas de un modelo.
#
# Este diccionario tiene un campo para indicar si es el conjunto de entrenamiento o prueba.
#
# Por ejemplo:
#
# ```json
#  {'dataset': 'train', 'precision': 0.8, 'balanced_accuracy': 0.7, 'recall': 0.9, 'f1_score': 0.85}
#  {'dataset': 'test', 'precision': 0.7, 'balanced_accuracy': 0.6, 'recall': 0.8, 'f1_score': 0.75}
# ```

# %%
from sklearn.metrics import precision_score, balanced_accuracy_score, recall_score, f1_score
import json

def calculate_metrics(model, X, y, dataset_name):
    y_pred = model.predict(X)
    
    precision = precision_score(y, y_pred)
    balanced_accuracy = balanced_accuracy_score(y, y_pred)
    recall = recall_score(y, y_pred)
    f1 = f1_score(y, y_pred)
    
    metrics = {
        'type': 'metrics',
        'dataset': dataset_name,
        'precision': precision,
        'balanced_accuracy': balanced_accuracy,
        'recall': recall,
        'f1_score': f1
    }
    return metrics

# %%
# Calcular métricas para el conjunto de entrenamiento y prueba
train_metrics = calculate_metrics(gridSearchCV.best_estimator_, x_train, y_train, 'train')
test_metrics = calculate_metrics(gridSearchCV.best_estimator_, x_test, y_test, 'test')

metrics = [train_metrics, test_metrics]

# %%
metrics
# Out:
# [{'type': 'metrics',
#   'dataset': 'train',
#   'precision': np.float64(0.9789542913515291),
#   'balanced_accuracy': np.float64(0.8129267194237689),
#   'recall': np.float64(0.6297863338269516),
#   'f1_score': np.float64(0.7664778578784758)},
#  {'type': 'metrics',
#   'dataset': 'test',
#   'precision': np.float64(0.6663778162911612),
#   'balanced_accuracy': np.float64(0.6742672652065836),
#   'recall': np.float64(0.4028287061288633),
#   'f1_score': np.float64(0.5021221025138752)}]

# %%
import json

def save_metrics(metrics, filename = "../files/output/metrics.json"):
    with open(filename, "a") as f:
        for metric in metrics:
            json.dump(metric,f)
            f.write('\n')

save_metrics(metrics)

# %% [markdown]
# # Paso 7: Calcular las matrices de confusión

# %% [markdown]
# Calcule las matrices de confusion para los conjuntos de entrenamiento y prueba. Guardelas en el archivo files/output/metrics.json. Cada fila del archivo es un diccionario con las metricas de un modelo de entrenamiento o prueba.
#
# Por ejemplo:
#
# ```json
# {'type': 'cm_matrix', 'dataset': 'train', 'true_0': {"predicted_0": 15562, "predicte_1": 666}, 'true_1': {"predicted_0": 3333, "predicted_1": 1444}}
# {'type': 'cm_matrix', 'dataset': 'test', 'true_0': {"predicted_0": 15562, "predicte_1": 650}, 'true_1': {"predicted_0": 2490, "predicted_1": 1420}}
# ```

# %%
from sklearn.metrics import confusion_matrix

cm_matrix_train = confusion_matrix(
    y_true=y_train,
    y_pred=y_pred_train,
)

cm_matrix_train

# %%
from sklearn.metrics import confusion_matrix

cm_matrix_test = confusion_matrix(
    y_true=y_test,
    y_pred=y_pred_test,
)

cm_matrix_test

# %%
from sklearn.metrics import confusion_matrix

# Calcular y guardar las matrices de confusión
def calculate_confusion_matrix(model, X, y, dataset_name):
    y_pred = model.predict(X)
    cm = confusion_matrix(y, y_pred)
    cm_dict = {
        'type': 'cm_matrix',
        'dataset': dataset_name,
        'true_0': {"predicted_0": int(cm[0, 0]), "predicted_1": int(cm[0, 1])},
        'true_1': {"predicted_0": int(cm[1, 0]), "predicted_1": int(cm[1, 1])}
    }
    return cm_dict

# %%
# Calcular matrices de confusión para el conjunto de entrenamiento y prueba
train_cm = calculate_confusion_matrix(gridSearchCV.best_estimator_, x_train, y_train, 'train')
test_cm = calculate_confusion_matrix(gridSearchCV.best_estimator_, x_test, y_test, 'test')

cm_matrices = [train_cm, test_cm]

# %%
import json

def save_confusion_matrices(cm_matrices, filename = "../files/output/metrics.json"):
    with open(filename, "a") as f:
        for cm in cm_matrices:
            json.dump(cm,f)
            f.write('\n')

save_confusion_matrices(cm_matrices)

# %%
all_metrics = metrics + cm_matrices
all_metrics
# Out:
# [{'dataset': 'train',
#   'precision': np.float64(0.8522195167634389),
#   'balanced_accuracy': np.float64(0.9570351555659204),
#   'recall': np.float64(0.9625555320499259),
#   'f1_score': np.float64(0.9040333796940194)},
#  {'dataset': 'test',
#   'precision': np.float64(0.5705882352941176),
#   'balanced_accuracy': np.float64(0.7025860180742468),
#   'recall': np.float64(0.5081194342587743),
#   'f1_score': np.float64(0.5375450263230812)},
#  {'type': 'cm_matrix',
#   'dataset': 'train',
#   'true_0': {'predicted_0': 15484, 'predicted_1': 789},
#   'true_1': {'predicted_0': 177, 'predicted_1': 4550}},
#  {'type': 'cm_matrix',
#   'dataset': 'test',
#   'true_0': {'predicted_0': 6361, 'predicted_1': 730},
#   'true_1': {'predicted_0': 939, 'predicted_1': 970}}]
